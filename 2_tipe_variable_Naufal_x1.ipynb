# %% [markdown]
# <a href="https://colab.research.google.com/github/naufalazhar2025/KKAsmt1/blob/main/2_tipe_variable_Naufal_x1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variabel

# %%
minyak_goreng = "30000"
print(minyak_goreng)
# Out:
# 30000

# %%
email_user_3 = "sampitak.2020@gmail.com"
print(email_user_3)
# Out:
# sampitak.2020@gmail.com

# %%
print(minyak_goreng,*10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2498563956.py in <cell line: 0>()
# ----> 1 print(minyak_goreng,*10)
#
# TypeError: Value after * must be an iterable, not int

# %% [markdown]
# Peraturan penulisan variabel

# %%
# penulisan variabel hanya boleh menggunakan huruf, angka dan underscore
# tidak boleh menggunakan spasi
nama narapidana = "Fulan dan falun"
print(nama_narapidana)
# Out:
#   File "/tmp/ipython-input-2034479030.py", line 3
#     nama narapidana = "Fulan dan falun"
#          ^
# SyntaxError: invalid syntax

# %%
# tidak boleh di awali dengan angka
1_aktivis_muda = dder
# Out:
#   File "/tmp/ipython-input-979946366.py", line 2
#     1_aktivis_muda = dder
#      ^
# SyntaxError: invalid decimal literal

# %%
# penulisan variabel itu case sensitive terhadap capslock
nama_siswa_3
print(nama_siswa_3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2228395333.py in <cell line: 0>()
#       1 # penulisan variabel itu case sensitive terhadap capslock
# ----> 2 nama_siswa_3
#       3 print(nama_siswa_3)
#
# NameError: name 'nama_siswa_3' is not defined

# %%
print(email_user_3)
# Out:
# sampitak.2020@gmail.com

# %%
# dilarang menggunakan kata kunci di bahasa python
print = "kajine"
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1650872152.py in <cell line: 0>()
#       1 # dilarang menggunakan kata kunci di bahasa python
#       2 print = "kajine"
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
kode_pyhton = "kajio"
print(kode_pyhton)
# Out:
# kajio

# %%
# deskriptif
_ = 'babon'
print(_)
# Out:
# babon

# %%
# tidak boleh pakai kata kunci python
# kalau eror, harus diconnect dulu
# print = "Devin"

# %% [markdown]
# Assignment

# %% [markdown]
# ##single Assignment

# %%
nama_siswa_2 = "irfan"
nama_siswa_4 = "djoe"
print(nama_siswa_2)
print(nama_siswa_4)
# Out:
# irfan
# djoe

# %% [markdown]
# ##Multi Assignment

# %%
nama_siswa_5, nama_siswa_6 = 'ale', 'fade'
print(nama_siswa_5)
print(nama_siswa_6)
# Out:
# ale
# fade

# %% [markdown]
# ##Assign ke banyak variabel sekaligus

# %%
nilai_A = nilai_B = nilai_C = 70
print(nilai_A)
print(nilai_B)
# Out:
# 70
# 70

# %% [markdown]
# #aritmatika

# %%
print("5000*3")
# Out:
# 5000*3

# %%
#operand tanpa disimpan dalam variabel
print(6000*9)
# Out:
# 54000

# %%
#simpan operand ke dalam variabel
harga_sate = 20000
banyak_porsi = 59
print(harga_sate*banyak_porsi)
# Out:
# 1180000

# %%
#simpan hasil operasi ke dalam variabel
harga_total_sate = 20000*59
print(harga_total_sate)
# Out:
# 1180000

# %%
#simpan nilai operand dan hasil operasi ke dalam variabel
harga_sate = 20000
jumlah_porsi = 59
harga_total_sate = harga_sate*jumlah_porsi
print(harga_total_sate)
# Out:
# 1180000

# %%
uang_yang_diterima = 200000
uang_kembalian = uang_yang_diterima - harga_total_sate
print(uang_kembalian)
# Out:
# -980000

# %%
jumlah_botol = 45
banyak_pengepul = 6
print(jumlah_botol*banyak_pengepul)
# Out:
# 270

# %%
total_jumlah = 24*3
print(total_jumlah)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
print(banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_jumlah_botol = banyak_botol_per_kardus*jumlah_kardus
print(total_jumlah_botol)
# Out:
# 72

# %%
 usia = 78
type(usia)
# Out:
# int

# %%
berat_telur = 5.5
type(berat_telur)
# Out:
# float

# %% [markdown]
# Tipe variable

# %%
nama = "Shinta"
type(nama)
# Out:
# str

# %%
remidi = False
type(remidi)
# Out:
# bool

# %%
remidi = True
type(remidi)
# Out:
# bool

# %%
koordinat_bintang = 1.5
type(koordinat_bintang)
# Out:
# float

# %%
Koordinat_titik = 9
type(Koordinat_titik)
# Out:
# int

# %% [markdown]
# Input

# %%
panjang = 20
lebar = 5
luas = panjang*lebar
print(luas)
# Out:
# 100

# %%
 input()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3780456608.py in <cell line: 0>()
# ----> 1 input()
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
# ...

# %%
input()
# Out:
# 12
# '12'

# %%
panjang = input()
# Out:
# 10

# %%
print(panjang)
# Out:
# 10

# %%
lebar = input()
# Out:
# 5

# %%
lebar = input()
# Out:
# 5

# %%
print(lebar)
# Out:
# 5

# %%
#tipe data masih string dan harus di convert ke interget atau float
luas = panjang*lebar
luas
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-821845708.py in <cell line: 0>()
#       1 #tipe data masih string dan harus di convert ke interget atau float
# ----> 2 luas = panjang*lebar
#       3 luas
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
panjang = int(panjang)

# %%
lebar = int(lebar)

# %%
type(panjang)
# Out:
# int

# %%
panjang_1 = int(input("Masukkan panjang persegi: "))
# Out:
# Masukkan panjang persegi: 10

# %%
panjang_2 = int(input("Masukkan panjang persegi: "))
lebar_2 = int(input("Masukkan lebar persegi: "))
luas_2 = panjang_2*lebar_2
print(f"luas persegi panjang adalah {luas_2} cm^2")
# Out:
# Masukkan panjang persegi: 4
# Masukkan lebar persegi: 10
# luas persegi panjang adalah 40 cm^2

# %%
panjang = 10
lebar = 5
tinggi = 5
V = panjang*lebar*tinggi
print(V)
# Out:
# 250

# %%
panjang = int(input("Masukkan panjang persegi (cm): "))
lebar = int(input("Masukkan lebar persegi (cm): "))
